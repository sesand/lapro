# %%
import torch 
print(torch.version.cuda)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 print(torch.version.cuda)
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !python -c "import torch; print(f'PyTorch version: {torch.__version__}'); print(f'Is CUDA available: {torch.cuda.is_available()}'); print(f'CUDA version: {torch.version.cuda}')" PyTorch version: 2.4.0
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "d:\laparoscopic_surgery_codings\training_yolo\.conda\lib\site-packages\torch\__init__.py", line 143, in <module>
#     raise err
# OSError: [WinError 126] The specified module could not be found. Error loading "d:\laparoscopic_surgery_codings\training_yolo\.conda\lib\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
# %ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 9874-B4E2
#
#  Directory of d:\laparoscopic_surgery_codings\training_yolo
#
# 27-08-2024  09:07    <DIR>          .
# 22-08-2024  13:01    <DIR>          ..
# 27-08-2024  09:10    <DIR>          .conda
# 27-08-2024  07:20           188,072 testing.ipynb
# 22-08-2024  12:43       404,478,783 yolo.ipynb
#                2 File(s)    404,666,855 bytes
#                3 Dir(s)  429,231,431,680 bytes free

# %%
# !nvidia-smi
# Out:
# Mon Aug 26 17:38:13 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 537.13                 Driver Version: 537.13       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Quadro T2000                 WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   74C    P0              20W /  30W |   3920MiB /  4096MiB |    100%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:09:35_Pacific_Daylight_Time_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
import torch
print(torch.__version__)
# Out:
# 2.3.1+cu121

# %%
# !python -c "import torch; print(f'PyTorch version: {torch.__version__}'); print(f'Is CUDA available: {torch.cuda.is_available()}'); print(f'CUDA version: {torch.version.cuda}')" PyTorch version: 2.4.0
# Out:
# PyTorch version: 2.3.1+cu121
# Is CUDA available: True
# CUDA version: 12.1

# %%
# !pip uninstall torch torchvision torchaudio -y
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     C:\Users\New\miniconda3
# crew_ai                  C:\Users\New\miniconda3\envs\crew_ai
# lapro                    C:\Users\New\miniconda3\envs\lapro
# training_yolo            C:\Users\New\miniconda3\envs\training_yolo
#                          D:\coding\.conda
#                          d:\coding\.conda
#                          d:\crew_ai\.conda
#                       *  d:\laparoscopic_surgery_codings\training_yolo\.conda
#                          d:\sam2\.conda

# %%
# !conda activate training_yolo

# %%
# !pip list
# Out:
# Package                Version
# ---------------------- ------------
# asttokens              2.4.1
# colorama               0.4.6
# comm                   0.2.2
# contourpy              1.2.1
# cycler                 0.12.1
# debugpy                1.8.5
# decorator              5.1.1
# exceptiongroup         1.2.2
# executing              2.0.1
# filelock               3.13.1
# filetype               1.2.0
# fonttools              4.53.1
# fsspec                 2024.2.0
# importlib_metadata     8.4.0
# intel-openmp           2021.4.0
# ipykernel              6.29.5
# ipython                8.26.0
# jedi                   0.19.1
# Jinja2                 3.1.3
# jupyter_client         8.6.2
# jupyter_core           5.7.2
# kiwisolver             1.4.5
# MarkupSafe             2.1.5
# matplotlib             3.9.2
# matplotlib-inline      0.1.7
# mkl                    2021.4.0
# mpmath                 1.3.0
# nest_asyncio           1.6.0
# networkx               3.2.1
# ...

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.7 GB 26.9 MB/s eta 0:01:40
#      ---------------------------------------- 0.0/2.7 GB 29.1 MB/s eta 0:01:33
#      ---------------------------------------- 0.0/2.7 GB 31.3 MB/s eta 0:01:26
#      ---------------------------------------- 0.0/2.7 GB 33.2 MB/s eta 0:01:21
#      ---------------------------------------- 0.0/2.7 GB 32.5 MB/s eta 0:01:22
#       --------------------------------------- 0.0/2.7 GB 34.0 MB/s eta 0:01:19
#       --------------------------------------- 0.0/2.7 GB 34.3 MB/s eta 0:01:18
#       --------------------------------------- 0.1/2.7 GB 34.5 MB/s eta 0:01:17
#       --------------------------------------- 0.1/2.7 GB 35.0 MB/s eta 0:01:16
#      - -------------------------------------- 0.1/2.7 GB 34.8 MB/s eta 0:01:16
# ...

# %%
# !pip install torch==2.3.1 torchvision==0.18.1 torchaudio==2.3.1 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/2.4 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.4 GB 16.8 MB/s eta 0:02:25
#      ---------------------------------------- 0.0/2.4 GB 23.1 MB/s eta 0:01:45
#      ---------------------------------------- 0.0/2.4 GB 22.4 MB/s eta 0:01:48
#      ---------------------------------------- 0.0/2.4 GB 25.7 MB/s eta 0:01:34
#      ---------------------------------------- 0.0/2.4 GB 26.9 MB/s eta 0:01:30
#       --------------------------------------- 0.0/2.4 GB 28.5 MB/s eta 0:01:24
#       --------------------------------------- 0.0/2.4 GB 28.6 MB/s eta 0:01:24
#       --------------------------------------- 0.0/2.4 GB 28.6 MB/s eta 0:01:24
#       --------------------------------------- 0.1/2.4 GB 28.2 MB/s eta 0:01:25
#       --------------------------------------- 0.1/2.4 GB 27.2 MB/s eta 0:01:28
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# True
# 12.1

# %%
# !nvidia-smi
# Out:
# Tue Aug 27 09:22:23 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 537.13                 Driver Version: 537.13       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Quadro T2000                 WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   57C    P8               4W /  40W |   3218MiB /  4096MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:09:35_Pacific_Daylight_Time_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
import torch
import torchvision

print(f"PyTorch version: {torch.__version__}")
print(f"torchvision version: {torchvision.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version detected by PyTorch: {torch.version.cuda}")
# Out:
# PyTorch version: 2.3.1+cu121
# torchvision version: 0.18.1+cu121
# CUDA available: True
# CUDA version detected by PyTorch: 12.1

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.10.14 torch-2.3.1+cu121 CUDA:0 (Quadro T2000, 4096MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 82.2/476.9 GB disk)

# %% [markdown]
# ROBOFLOW dataset download

# %% [markdown]
# laparoscopic dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SsUc859NGJaa1WtC31Ry")
project = rf.workspace("gb-edrki").project("laparoscopic_dadasets01")
version = project.version(9)
dataset = version.download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to laparoscopic_dadasets01-9 in yolov8:: 100%|██████████| 3998/3998 [00:08<00:00, 449.99it/s]

# %%
# %ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 9874-B4E2
#
#  Directory of d:\laparoscopic_surgery_codings\training_yolo
#
# 27-08-2024  09:48    <DIR>          .
# 22-08-2024  13:01    <DIR>          ..
# 27-08-2024  09:10    <DIR>          .conda
# 27-08-2024  09:36    <DIR>          laparoscopic_dadasets01-9
# 27-08-2024  09:50           211,431 testing.ipynb
# 22-08-2024  12:43       404,478,783 yolo.ipynb
# 27-08-2024  09:48        23,897,299 yolov8s-seg.pt
#                3 File(s)    428,587,513 bytes
#                4 Dir(s)  423,631,216,640 bytes free

# %%
# %cd laparoscopic_dadasets01-9/
# Out:
# d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SsUc859NGJaa1WtC31Ry")
project = rf.workspace("gb-edrki").project("laparoscopic_dataset_293frames")
version = project.version(2)
dataset = version.download("yolov8")

# %%
import torch
from ultralytics import YOLO
import yaml
import os

# Verify GPU availability
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU device name:", torch.cuda.get_device_name(0))

# Load a pretrained YOLOv8 model
model = YOLO('yolov8s-seg.pt')

# Set the device to GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

# Print the current working directory
current_directory = os.getcwd()
print("Current working directory:", current_directory)

# Path to your data.yaml file (assumed relative to current directory)
data_yaml_path = os.path.join(current_directory, 'data.yaml')

# Verify the paths inside data.yaml
with open(data_yaml_path, 'r') as file:
    data_yaml = yaml.safe_load(file)

train_path = os.path.join(current_directory, data_yaml.get('train', ''))
val_path = os.path.join(current_directory, data_yaml.get('val', ''))

print(f"Train images path: {train_path}")
print(f"Validation images path: {val_path}")

# Check if the paths exist
if not os.path.exists(train_path):
    print(f"Error: Training path does not exist: {train_path}")
else:
    print(f"Training path verified: {train_path}")

if not os.path.exists(val_path):
    print(f"Error: Validation path does not exist: {val_path}")
else:
    print(f"Validation path verified: {val_path}")

# Train the model
try:
    model.train(
        task='segment',
        data=data_yaml_path,
        epochs=5,
        imgsz=640,
        batch=32,
        device=device,
        lr0=0.0001
    )
except Exception as e:
    print("An error occurred during training:", e)
# Out:
# ...
# PyTorch version: 2.3.1+cu121
# CUDA available: True
# GPU device name: Quadro T2000
# 100%|██████████| 22.8M/22.8M [00:01<00:00, 19.0MB/s]
# Current working directory: d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9
# Train images path: d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9\train/images
# Validation images path: d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9\valid/images
# Training path verified: d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9\train/images
# Validation path verified: d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9\valid/images
# New https://pypi.org/project/ultralytics/8.2.82 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.10.14 torch-2.3.1+cu121 CUDA:0 (Quadro T2000, 4096MiB)
# ...

# %%
import torch

# List all available GPUs
for i in range(torch.cuda.device_count()):
    print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# GPU 0: Quadro T2000

# %%
import torch
from ultralytics import YOLO
import yaml
import os

# Verify GPU availability
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

# List available GPUs and ensure we have the correct index for Quadro T2000
for i in range(torch.cuda.device_count()):
    print(f"GPU {i}: {torch.cuda.get_device_name(i)}")

# Set the device to GPU 0 (which should correspond to Quadro T2000)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Print the selected device
print(f"Selected device: {device}")

# Load a pretrained YOLOv8 model
model = YOLO('yolov8s-seg.pt')

# Move model to the specified device
model.to(device)

# Print the current working directory
current_directory = os.getcwd()
print("Current working directory:", current_directory)

# Path to your data.yaml file (assumed relative to current directory)
data_yaml_path = os.path.join(current_directory, 'data.yaml')

# Verify the paths inside data.yaml
with open(data_yaml_path, 'r') as file:
    data_yaml = yaml.safe_load(file)

train_path = os.path.join(current_directory, data_yaml.get('train', ''))
val_path = os.path.join(current_directory, data_yaml.get('val', ''))

print(f"Train images path: {train_path}")
print(f"Validation images path: {val_path}")

# Check if the paths exist
if not os.path.exists(train_path):
    print(f"Error: Training path does not exist: {train_path}")
else:
    print(f"Training path verified: {train_path}")

if not os.path.exists(val_path):
    print(f"Error: Validation path does not exist: {val_path}")
else:
    print(f"Validation path verified: {val_path}")

# Train the model
try:
    model.train(
        task='segment',
        data=data_yaml_path,
        epochs=5,
        imgsz=640,
        batch=32,
        device=device,
        lr0=0.0001
    )
except Exception as e:
    print("An error occurred during training:", e)
# Out:
# PyTorch version: 2.3.1+cu121
# CUDA available: True
# GPU 0: Quadro T2000
# Selected device: cuda:0
# Current working directory: d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9
# Train images path: d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9\train/images
# Validation images path: d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9\valid/images
# Training path verified: d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9\train/images
# Validation path verified: d:\laparoscopic_surgery_codings\training_yolo\laparoscopic_dadasets01-9\valid/images
# New https://pypi.org/project/ultralytics/8.2.82 available  Update with 'pip install -U ultralytics'
# ...

# %% [markdown]
# TRAINING (using yolo model) - Instance segment model

# %% [markdown]
# training (laparoscopic_datasets_01-09)

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data={dataset.location}/data.yaml epochs=1 imgsz=640 batch=32

# %% [markdown]
# VALIDATION (laparoscopic_datasets_01-09)

# %%
# !yolo task=segment mode=val model=yolov8s-seg.pt data={dataset.location}/data.yaml

# %% [markdown]
# TESTING

# %%
# !yolo task=segment mode=predict model=gb/best.pt source='gb/videos/VideoCutter_video002.mp4'

# %% [markdown]
# to find current working directory

# %%
import os

print("Current working directory:", os.getcwd())

# %% [markdown]
# List out the folders for current working directory

# %%
import os

# List files in the current working directory
print("Files in 'C:\\Users\\New\\gb':", os.listdir())

# %% [markdown]
# INSTANCE SEGMENTATION (for teting without bouding box)

# %%
import os
import cv2
from ultralytics import YOLO
from ultralytics.utils.plotting import colors
from base64 import b64encode
from IPython.display import HTML

# Absolute paths for model and video
model_path = os.path.abspath("runs/segment/train12/weights/best.pt")
video_path = os.path.abspath("gb/videos/VideoCutter_video002.mp4")

# Check if the model file exists
if not os.path.isfile(model_path):
    raise FileNotFoundError(f"Model file not found: {model_path}")

# Check if the video file exists
if not os.path.isfile(video_path):
    raise FileNotFoundError(f"Video file not found: {video_path}")

# Load the model
model = YOLO(model_path)  # segmentation model
names = model.model.names

# Load the video
cap = cv2.VideoCapture(video_path)
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Check if video is loaded successfully
if not cap.isOpened():
    raise Exception("Error: Could not open video.")

# Define the codec and create VideoWriter object for MP4 format
output_path_mp4 = "segmentation_001.mp4"
out = cv2.VideoWriter(output_path_mp4, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    # Run inference
    results = model.predict(im0)

    if results[0].masks is not None:
        clss = results[0].boxes.cls.cpu().tolist()
        masks = results[0].masks.xy
        for mask, cls in zip(masks, clss):
            color = colors(int(cls), True)
            pts = mask.reshape((-1, 1, 2)).astype(int)
            cv2.polylines(im0, [pts], isClosed=True, color=color, thickness=2)
            cv2.putText(im0, names[int(cls)], (pts[0][0][0], pts[0][0][1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    # Write the frame to the output video
    out.write(im0)

# Release resources
out.release()
cap.release()

# Check if MP4 file was created successfully
if not os.path.isfile(output_path_mp4):
    raise FileNotFoundError(f"MP4 file not created: {output_path_mp4}")

# Show the resulting video
def show_video(file_name, width=640):
    mp4 = open(file_name, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML("""
    <video width="{0}" controls>
        <source src="{1}" type="video/mp4">
    </video>
    """.format(width, data_url))

# Display the output video
show_video(output_path_mp4, width=960)

# %%
import os
import cv2
from ultralytics import YOLO
from ultralytics.utils.plotting import colors
from base64 import b64encode
from IPython.display import HTML

# Absolute paths for model and video
model_path = os.path.abspath("runs/segment/train12/weights/best.pt")
video_path = os.path.abspath("gb/videos/video004.mp4")

# Check if the model file exists
if not os.path.isfile(model_path):
    raise FileNotFoundError(f"Model file not found: {model_path}")

# Check if the video file exists
if not os.path.isfile(video_path):
    raise FileNotFoundError(f"Video file not found: {video_path}")

# Load the model
model = YOLO(model_path)  # segmentation model
names = model.model.names

# Load the video
cap = cv2.VideoCapture(video_path)
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Check if video is loaded successfully
if not cap.isOpened():
    raise Exception("Error: Could not open video.")

# Define the codec and create VideoWriter object for MP4 format
output_path_mp4 = "gb002/testing_videos/instance_segmentation_video_004.mp4"
out = cv2.VideoWriter(output_path_mp4, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    # Run inference
    results = model.predict(im0)

    if results[0].masks is not None:
        clss = results[0].boxes.cls.cpu().tolist()
        masks = results[0].masks.xy
        for mask, cls in zip(masks, clss):
            color = colors(int(cls), True)
            pts = mask.reshape((-1, 1, 2)).astype(int)
            cv2.polylines(im0, [pts], isClosed=True, color=color, thickness=2)
            cv2.putText(im0, names[int(cls)], (pts[0][0][0], pts[0][0][1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    # Write the frame to the output video
    out.write(im0)

# Release resources
out.release()
cap.release()

# Check if MP4 file was created successfully
if not os.path.isfile(output_path_mp4):
    raise FileNotFoundError(f"MP4 file not created: {output_path_mp4}")

# Show the resulting video
def show_video(file_name, width=640):
    mp4 = open(file_name, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML("""
    <video width="{0}" controls>
        <source src="{1}" type="video/mp4">
    </video>
    """.format(width, data_url))

# Display the output video
show_video(output_path_mp4, width=960)

# %% [markdown]
# testing with light colors (instance segmentation) - less opacity

# %%
import os
import cv2
import numpy as np
from ultralytics import YOLO
from base64 import b64encode
from IPython.display import HTML

# Absolute paths for model and video
model_path = os.path.abspath("best.pt")
video_path = os.path.abspath("videos/video001.mp4")

# Check if the model file exists
if not os.path.isfile(model_path):
    raise FileNotFoundError(f"Model file not found: {model_path}")

# Check if the video file exists
if not os.path.isfile(video_path):
    raise FileNotFoundError(f"Video file not found: {video_path}")

# Load the model
model = YOLO(model_path)  # segmentation model
names = model.model.names

# Load the video
cap = cv2.VideoCapture(video_path)
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Check if video is loaded successfully
if not cap.isOpened():
    raise Exception("Error: Could not open video.")

# Define the codec and create VideoWriter object for MP4 format
output_path_mp4 = "instance_segmentation_light_video002.mp4"
out = cv2.VideoWriter(output_path_mp4, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Define light colors for each class
class_colors = {
    'gallbladder': [152, 240, 155],  # Light green
    'liver': [255, 51, 51],          # Light red
    'tool': [240, 140, 8],           # Light orange
    'cystic duct': [238, 232, 73],   # Light yellow
}

opacity = 0.2  # Set the desired opacity (0.0 to 1.0)

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    # Run inference
    results = model.predict(im0)

    if results[0].masks is not None:
        clss = results[0].boxes.cls.cpu().tolist()
        masks = results[0].masks.xy  # Use xy attribute

        for mask, cls in zip(masks, clss):
            class_name = names[int(cls)]
            if class_name in class_colors:
                color = class_colors[class_name]
            else:
                # If class color is not defined, use a default light color
                color = [255, 255, 255]  # Light grey

            mask = np.array(mask, dtype=np.int32).reshape((-1, 1, 2))
            overlay = im0.copy()
            cv2.fillPoly(overlay, [mask], color=color)
            cv2.polylines(overlay, [mask], isClosed=True, color=(0, 0, 0), thickness=2)
            im0 = cv2.addWeighted(overlay, opacity, im0, 1 - opacity, 0)

            # Add class name text
            cv2.putText(im0, class_name, (mask[0][0][0], mask[0][0][1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 0), 2)

    # Write the frame to the output video
    out.write(im0)

# Release resources
out.release()
cap.release()

# Check if MP4 file was created successfully
if not os.path.isfile(output_path_mp4):
    raise FileNotFoundError(f"MP4 file not created: {output_path_mp4}")

# Show the resulting video
def show_video(file_name, width=640):
    mp4 = open(file_name, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML("""
    <video width="{0}" controls>
        <source src="{1}" type="video/mp4">
    </video>
    """.format(width, data_url))

# Display the output video
show_video(output_path_mp4, width=960)
